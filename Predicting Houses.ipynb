# %%
#to plot inside the notebook
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Load some house sales data

# %%
sales = pd.read_csv("home_data.csv")

# %%
sales
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 2      5631500400  20150225T000000   180000         2       1.00          770
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# 6      1321400060  20140627T000000   257500         3       2.25         1715
# 7      2008000270  20150115T000000   291850         3       1.50         1060
# 8      2414600126  20150415T000000   229500         3       1.00         1780
# 9      3793500160  20150312T000000   323000         3       2.50         1890
# 10     1736800520  20150403T000000   662500         3       2.50         3560
# ...

# %% [markdown]
# #Exploring the data for housing sales

# %%
plt.scatter(sales['sqft_living'], sales['price'])
#remove scientific notation
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,1000000000))
plt.show()
# Out:
# D:\conda1\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# #Create a simple regression model of sqft_living to price

# %%
from sklearn.cross_validation import train_test_split
train_data,test_data = train_test_split(sales,train_size=0.8)

# %%
train_data.head()
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 16868  4315700275  20141107T000000  590000         4       2.50         2380
# 21042  1389600040  20141226T000000  255000         4       2.50         1987
# 20717  9352900200  20150407T000000  285000         3       2.50         1320
# 9743   6071300030  20140624T000000  464500         3       1.75         1150
# 18092  2560800165  20150316T000000  180500         2       1.00          850
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 16868      4950       2           0     0     ...          8        2380
# 21042      6000       2           0     0     ...          7        1987
# 20717       955       3           0     0     ...          7        1320
# 9743      10466       1           0     0     ...          7        1150
# 18092      5000       1           0     0     ...          6         850
#
# ...

# %%
len(train_data)
# Out:
# 17290

# %%
test_data.head()
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 21254  7852120050  20150311T000000   729950         4       3.50         3510
# 19786  7899800791  20141023T000000   230000         3       2.00         1160
# 17629  1247100035  20140630T000000  1095000         4       2.75         3330
# 10819   164000267  20141016T000000   311300         2       1.00         1000
# 19167  3356402020  20140508T000000   230000         3       1.00         1390
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 21254     10010       2           0     0     ...         10        3510
# 19786      1174       2           0     0     ...          7         790
# 17629      9143       2           0     0     ...         10        3330
# 10819      7228       1           0     0     ...          7        1000
# 19167     16000       1           0     0     ...          6        1390
#
# ...

# %%
len(test_data)
# Out:
# 4323

# %% [markdown]
# #Build the regression the model

# %%
from sklearn.linear_model import LinearRegression
X = train_data[['sqft_living']]
y=train_data.price
#build the linear regression object
lm=LinearRegression()
# Train the model using the training sets
lm.fit(X,y)
#print the y intercept
print(lm.intercept_)
#print the coefficents
print(lm.coef_)
# Out:
# -43222.7257375
# [ 280.27121412]

# %% [markdown]
# The Linear Model of the houses is  -40151.42 + 278.29X

# %%
feature_cols=train_data['sqft_living']
pair=zip(feature_cols,lm.coef_)

# %% [markdown]
# #Predict the Price of a House if the Living Space was 300 square feet

# %%
lm.predict(300)
# Out:
# array([ 40858.63849799])

# %%
#calculate squared
lm.score(X,y)
# Out:
# 0.48878433338869054

# %% [markdown]
# #Evaluate the simple model

# %%
print(test_data['price'].mean())
# Out:
# 544996.7797825584

# %%
y_true= train_data['price'].mean()
y_pred=test_data['price'].mean()
y_pred
# Out:
# 544996.7797825584

# %%
from math import sqrt
population_size=len(test_data)
math.sqrt(.25/population_size)
# Out:
# 0.007604617709126885

# %%
#np.mean((regr.predict(diabetes_X_test) - diabetes_y_test) ** 2))np.mean((regr.predict(diabetes_X_test) - diabetes_y_test) ** 2))

# %%
from sklearn.metrics import mean_squared_error
n=len(test_data)
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
enc.fit(test_data[['price']])
q=enc.n_values_
enc.fit(train_data[['price']])
w=enc.n_values_
#enc.fit(test_data[['prices']])
RSME= mean_squared_error(w,q)**2
RSME
RMSE = mean_squared_error(q, w)**0.5
RSME
(w-q)/2



    
#np.linalg.norm(test_data[['price']]-train_data[['price']])/np.sqrt(N)
# Out:
# array([ 407500.])

# %% [markdown]
# #Let's show what our predictions look like
